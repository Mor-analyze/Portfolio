# %%
import pandas as pd
import numpy as np

# %%
df_can = pd.read_excel('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows= range(20),
    skipfooter=2)

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 43 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Type      195 non-null    object
#  1   Coverage  195 non-null    object
#  2   OdName    195 non-null    object
#  3   AREA      195 non-null    int64
#  4   AreaName  195 non-null    object
#  5   REG       195 non-null    int64
#  6   RegName   195 non-null    object
#  7   DEV       195 non-null    int64
#  8   DevName   195 non-null    object
#  9   1980      195 non-null    int64
#  10  1981      195 non-null    int64
#  11  1982      195 non-null    int64
#  12  1983      195 non-null    int64
#  13  1984      195 non-null    int64
#  14  1985      195 non-null    int64
#  15  1986      195 non-null    int64
#  16  1987      195 non-null    int64
#  17  1988      195 non-null    int64
#  18  1989      195 non-null    int64
#  19  1990      195 non-null    int64
# ...

# %%
print(type(df_can.columns.tolist()))
print(type(df_can.index.tolist()))
# Out:
# <class 'list'>
# <class 'list'>

# %%
# Droping the extra Columns
df_can.drop(['AREA','REG','DEV','Type','Coverage'], axis=1, inplace=True)

# %%
# renaming the remaining columns
df_can.rename(columns={'OdName':'Country', 'AreaName':'Continent', 'RegName':'Region'}, inplace=True)
df_can.columns
# Out:
# Index([  'Country', 'Continent',    'Region',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
# Creating a total coloumns for total immigrant from each country 
df_can['Total'] = df_can.iloc[:,4:].sum(axis=1)

# %%
df_can.head(2)
# Out:
#        Country Continent           Region             DevName  1980  1981  \
# 0  Afghanistan      Asia    Southern Asia  Developing regions    16    39
# 1      Albania    Europe  Southern Europe   Developed regions     1     0
#
#    1982  1983  1984  1985  ...  2005  2006  2007  2008  2009  2010  2011  \
# 0    39    47    71   340  ...  3436  3009  2652  2111  1746  1758  2203
# 1     0     0     0     0  ...  1223   856   702   560   716   561   539
#
#    2012  2013  Total
# 0  2635  2004  58639
# 1   620   603  15699
#
# [2 rows x 39 columns]

# %%
# cheching for any null objects in the dataset
df_can.isnull().sum()
# Out:
# Continent    0
# Region       0
# DevName      0
# 1980         0
# 1981         0
# 1982         0
# 1983         0
# 1984         0
# 1985         0
# 1986         0
# 1987         0
# 1988         0
# 1989         0
# 1990         0
# 1991         0
# 1992         0
# 1993         0
# 1994         0
# 1995         0
# 1996         0
# 1997         0
# 1998         0
# 1999         0
# 2000         0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# 2007         0
# 2008         0
# 2009         0
# 2010         0
# 2011         0
# 2012         0
# 2013         0
# Total        0
# dtype: int64

# %%
df_can.describe()
# Out:
#                1980          1981          1982          1983          1984  \
# count    195.000000    195.000000    195.000000    195.000000    195.000000
# mean     508.394872    566.989744    534.723077    387.435897    376.497436
# std     1949.588546   2152.643752   1866.997511   1204.333597   1198.246371
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%       13.000000     10.000000     11.000000     12.000000     13.000000
# 75%      251.500000    295.500000    275.000000    173.000000    181.000000
# max    22045.000000  24796.000000  20620.000000  10015.000000  10170.000000
#
#               1985         1986          1987          1988          1989  \
# count   195.000000   195.000000    195.000000    195.000000    195.000000
# mean    358.861538   441.271795    691.133333    714.389744    843.241026
# ...

# %%
df_can[['Country',1980,1981,1982,1983,1984,1985]].head()
# Out:
#           Country  1980  1981  1982  1983  1984  1985
# 0     Afghanistan    16    39    39    47    71   340
# 1         Albania     1     0     0     0     0     0
# 2         Algeria    80    67    71    69    63    44
# 3  American Samoa     0     1     0     0     0     0
# 4         Andorra     0     0     0     0     0     0

# %% [markdown]
# ## Set Index

# %%
# numeric index makes it very difficult to do a query by a specific country
# setting the 'Country' column as the index
df_can.set_index('Country',inplace= True)

# %%
df_can.head(2)
# Out:
#             Continent           Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Country                              ...
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
# Albania         0     0     0     1  ...  1223   856   702   560   716   561
#
#              2011  2012  2013  Total
# Country
# Afghanistan  2203  2635  2004  58639
# Albania       539   620   603  15699
#
# [2 rows x 38 columns]

# %%
# remove The name of the index
df_can.index.name = None

# %%
df_can.head(2)
# Out:
#             Continent           Region             DevName  1980  1981  1982  \
# Afghanistan      Asia    Southern Asia  Developing regions    16    39    39
# Albania        Europe  Southern Europe   Developed regions     1     0     0
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
# Albania         0     0     0     1  ...  1223   856   702   560   716   561
#
#              2011  2012  2013  Total
# Afghanistan  2203  2635  2004  58639
# Albania       539   620   603  15699
#
# [2 rows x 38 columns]

# %% [markdown]
# ## Indexing and Filtering

# %%
# In the following lines, I implemented my indexing skills

# %%
df_can.loc['Japan']
# Out:
# Continent                 Asia
# Region            Eastern Asia
# DevName      Developed regions
# 1980                       701
# 1981                       756
# 1982                       598
# 1983                       309
# 1984                       246
# 1985                       198
# 1986                       248
# 1987                       422
# 1988                       324
# 1989                       494
# 1990                       379
# 1991                       506
# 1992                       605
# 1993                       907
# 1994                       956
# 1995                       826
# 1996                       994
# 1997                       924
# 1998                       897
# 1999                      1083
# 2000                      1010
# 2001                      1092
# 2002                       806
# 2003                       817
# 2004                       973
# 2005                      1067
# 2006                      1212
# ...

# %%
df_can.loc['Japan','2013']
# Out:
# 982

# %%
df_can.loc['Japan',[1980,1981,1982]]
# Out:
# 1980    701
# 1981    756
# 1982    598
# Name: Japan, dtype: object

# %%
df_can.loc[['Japan', 'Albania']]
# Out:
#         Continent           Region            DevName  1980  1981  1982  1983  \
# Japan        Asia     Eastern Asia  Developed regions   701   756   598   309
# Albania    Europe  Southern Europe  Developed regions     1     0     0     0
#
#          1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  \
# Japan     246   198   248  ...  1067  1212  1250  1284  1194  1168  1265
# Albania     0     0     1  ...  1223   856   702   560   716   561   539
#
#          2012  2013  Total
# Japan    1214   982  27707
# Albania   620   603  15699
#
# [2 rows x 38 columns]

# %%
# Column names that are integers (such as the years) might introduce some confusion
# converting integer columns to string
df_can.columns= list(map(str,df_can.columns))

# %%
df_can.columns
# Out:
# Index(['Continent', 'Region', 'DevName', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', 'Total'],
#       dtype='object')

# %%
# Create a list of years for easier ploting later on
years = list(map(str, range(1980,2014)))
years[:5]
# Out:
# ['1980', '1981', '1982', '1983', '1984']

# %% [markdown]
# ## Filtering <a id="4"></a>

# %%
# select only countries in Asia
condition = df_can['Continent'] == 'Asia'

# %%
df_can[condition].head()
# Out:
#             Continent         Region             DevName  1980  1981  1982  \
# Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
# Armenia          Asia   Western Asia  Developing regions     0     0     0
# Azerbaijan       Asia   Western Asia  Developing regions     0     0     0
# Bahrain          Asia   Western Asia  Developing regions     0     2     1
# Bangladesh       Asia  Southern Asia  Developing regions    83    84    86
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
# Armenia         0     0     0     0  ...   224   218   198   205   267   252
# Azerbaijan      0     0     0     0  ...   359   236   203   125   165   209
# Bahrain         1     1     3     0  ...    12    12    22     9    35    28
# Bangladesh     81    98    92   486  ...  4171  4014  2897  2939  2104  4721
#
#              2011  2012  2013  Total
# ...

# %%
# Using multiple filters
df_can[(df_can['Continent']=='Asia') & (df_can['Region'] =='Southern Asia')].head()
# Out:
#                            Continent         Region             DevName  1980  \
# India                           Asia  Southern Asia  Developing regions  8880
# Pakistan                        Asia  Southern Asia  Developing regions   978
# Iran (Islamic Republic of)      Asia  Southern Asia  Developing regions  1172
# Sri Lanka                       Asia  Southern Asia  Developing regions   185
# Bangladesh                      Asia  Southern Asia  Developing regions    83
#
#                             1981  1982  1983  1984  1985  1986  ...   2005  \
# India                       8670  8147  7338  5704  4211  7150  ...  36210
# Pakistan                     972  1201   900   668   514   691  ...  14314
# Iran (Islamic Republic of)  1429  1822  1592  1977  1648  1794  ...   5837
# Sri Lanka                    371   290   197  1086   845  1838  ...   4930
# Bangladesh                    84    86    81    98    92   486  ...   4171
#
# ...

# %% [markdown]
# ## Sorting

# %%
# sort the data frame by total coloumns
df_can.sort_values(by='Total',axis=0, ascending=False, inplace= True)

# %%
# Select the top 5 countries
top_5 = df_can.head(5)
top_5
# Out:
#                                                    Continent  \
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# India                                               Developing regions   8880
# ...

# %%
# top countris in year 2010
top_3_2010 = df_can.sort_values(by='2010',axis=0,ascending=False).head(3)

# %%
top_3_2010[['2010']]
# Out:
#               2010
# Philippines  38617
# India        34235
# China        30391

# %% [markdown]
# ## Ploting

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# select a style from avalable styles for ploting
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
mpl.style.use(['ggplot'])

# %% [markdown]
# ## Ploting immigration from Haiti

# %%
Haiti = df_can.loc['Haiti',years]

# %%
Haiti.plot(kind ='line')

plt.title('Immigration from Haiti')
plt.ylabel('Number of immigrants')
plt.xlabel('Years')

#added a note on the plot for more information
plt.text(20, 6000, '2010 Earthquake') 

plt.show()

# %%
# We can clearly notice how number of immigrants from Haiti spiked up from 2010 as Canada stepped up its efforts to accept refugees from Haiti. 
# I annotated that spike in the plot

# %% [markdown]
# ## Comparing the number of immigrants from India and China from 1980 to 2013.

# %%
df_CI= df_can.loc[['China','India'],years]

# %%
# Since `df_CI` is a dataframe with the `country` as the index and `years` as the columns, 
# we must first transpose the dataframe using `transpose()` method to swap the rows and columns.

df_CI = df_CI.transpose()
df_CI.head()
# Out:
#       China  India
# 1980   5123   8880
# 1981   6682   8670
# 1982   3308   8147
# 1983   1863   7338
# 1984   1527   5704

# %%
df_CI.plot(kind='line')

plt.title('Immigrants from China and India')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# ## Comparing the trend of top 5 countries that contributed the most to immigration to Canada

# %%
top_5 = top_5[years].transpose()

# %%
top_5.plot(kind='line', figsize=(14,8))

plt.title('Immigration Trend of Top 5 Countries')
plt.ylabel('Number of Immigrants')
plt.xlabel('Years')


plt.show()
